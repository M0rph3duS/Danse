# %%
import datetime

# %%
help(datetime.strptime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 help(datetime.strptime)
#
# AttributeError: module 'datetime' has no attribute 'strptime'
